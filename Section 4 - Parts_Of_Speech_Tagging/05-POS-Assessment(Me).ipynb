# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Parts of Speech Assessment

# %% [markdown]
# For this assessment we'll be using the short story [The Tale of Peter Rabbit](https://en.wikipedia.org/wiki/The_Tale_of_Peter_Rabbit) by Beatrix Potter (1902). <br>The story is in the public domain; the text file was obtained from [Project Gutenberg](https://www.gutenberg.org/ebooks/14838.txt.utf-8).

# %%
# RUN THIS CELL to perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')
from spacy import displacy

# %% [markdown]
# **1. Create a Doc object from the file `peterrabbit.txt`**<br>
# > HINT: Use `with open('../TextFiles/peterrabbit.txt') as f:`

# %%
with open('peterrabbit.txt', errors='ignore') as f:
    doc = nlp(f.read())

# %% [markdown]
# **2. For every token in the third sentence, print the token text, the POS tag, the fine-grained TAG tag, and the description of the fine-grained tag.**

# %%
# Bruh :D
i = 0 
for sent in doc.sents:
    if i == 2:
        print(sent)
        break
    i = i + 1
# Out:
# They lived with their Mother in a sand-bank, underneath the root of a
# very big fir-tree.

# %%
# Enter your code here:
for token in list(doc.sents)[2]:
    print(f"{token.text:{10}} {token.pos_:{10}} {token.tag_:{10}} {spacy.explain(token.tag_)}")
# Out:
# They       PRON       PRP        pronoun, personal
# lived      VERB       VBD        verb, past tense
# with       ADP        IN         conjunction, subordinating or preposition
# their      ADJ        PRP$       pronoun, possessive
# Mother     PROPN      NNP        noun, proper singular
# in         ADP        IN         conjunction, subordinating or preposition
# a          DET        DT         determiner
# sand       NOUN       NN         noun, singular or mass
# -          PUNCT      HYPH       punctuation mark, hyphen
# bank       NOUN       NN         noun, singular or mass
# ,          PUNCT      ,          punctuation mark, comma
# underneath ADP        IN         conjunction, subordinating or preposition
# the        DET        DT         determiner
# root       NOUN       NN         noun, singular or mass
# of         ADP        IN         conjunction, subordinating or preposition
# a          DET        DT         determiner
#
#           SPACE                 None
# ...

# %% [markdown]
# **3. Provide a frequency list of POS tags from the entire document**

# %%
POS_counts = doc.count_by(spacy.attrs.POS)
POS_counts
# Out:
# {96: 174,
#  99: 182,
#  102: 99,
#  83: 83,
#  84: 127,
#  85: 75,
#  88: 61,
#  89: 90,
#  91: 176,
#  92: 8,
#  93: 36,
#  94: 72,
#  95: 75}

# %%
for k,v in sorted(POS_counts.items()):
    print(f"ID: {k}. POS: {doc.vocab[k].text:{5}} {v} Counts")
# Out:
# ID: 83. POS: ADJ   83 Counts
# ID: 84. POS: ADP   127 Counts
# ID: 85. POS: ADV   75 Counts
# ID: 88. POS: CCONJ 61 Counts
# ID: 89. POS: DET   90 Counts
# ID: 91. POS: NOUN  176 Counts
# ID: 92. POS: NUM   8 Counts
# ID: 93. POS: PART  36 Counts
# ID: 94. POS: PRON  72 Counts
# ID: 95. POS: PROPN 75 Counts
# ID: 96. POS: PUNCT 174 Counts
# ID: 99. POS: VERB  182 Counts
# ID: 102. POS: SPACE 99 Counts

# %% [markdown]
# **4. CHALLENGE: What percentage of tokens are nouns?**<br>
# HINT: the attribute ID for 'NOUN' is 91

# %%
len(doc)
# Out:
# 1258

# %%
100 * POS_counts[91] / len(doc)
# Out:
# 13.990461049284578

# %% [markdown]
# **5. Display the Dependency Parse for the third sentence**

# %%
# displacy.render(list(doc.sents)[2], style='ent', jupyter=True)

displacy.render(list(doc.sents)[2], style='dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="3550" height="749.5" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">They</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">lived</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# ...

# %% [markdown]
# **6. Show the first two named entities from Beatrix Potter's *The Tale of Peter Rabbit* **

# %%
# doc.ents  (All Entities)
# doc.ents[2]     (The First Two Entities)

for ent in doc.ents[:2]:
    print(ent.text + ' | ' + ent.label_ + ' | ' + str(spacy.explain(ent.label_)))
# Out:
# The Tale of Peter Rabbit | WORK_OF_ART | Titles of books, songs, etc.
# Beatrix Potter | PERSON | People, including fictional

# %% [markdown]
# **7. How many sentences are contained in *The Tale of Peter Rabbit*?**

# %%
len(list(doc.sents))
# Out:
# 56

# %% [markdown]
# **8. CHALLENGE: How many sentences contain named entities?**

# %%
list_of_sents = [nlp(sent.text) for sent in doc.sents]

list_of_sents_with_ners = [doc for doc in list_of_sents if doc.ents]

len(list_of_sents_with_ners)
# Out:
# 49

# %% [markdown]
# **9. CHALLENGE: Display the named entity visualization for `list_of_sents[0]` from the previous problem**

# %%
displacy.render(list_of_sents_with_ners[0], style='ent',jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     The Tale of Peter Rabbit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Beatrix Potter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# ...

# %%
# Whole Document :D
displacy.render(doc, style='ent',jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     The Tale of Peter Rabbit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Beatrix Potter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# ...

# %% [markdown]
# ### Great Job!
